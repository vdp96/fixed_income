# %%
import os
import datetime

import pandas as pd
import numpy as np
import fi_utils
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# directories
BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, "data")

# %% [markdown]
# ## Extrapolating interest rates using Nelson Siegel Svensson Model

# %%
# Yield data from :https://www.federalreserve.gov/data/nominal-yield-curve.htm
yield_file = os.path.join(DATA_DIR, "feds200628.csv")
fed_df = pd.read_csv(yield_file, skiprows=9)
fed_df["Date"] = pd.to_datetime(fed_df["Date"])
fed_df.head()
# Out:
#         Date     BETA0     BETA1     BETA2  BETA3  SVEN1F01  SVEN1F04  \
# 0 1961-06-14  3.917606 -1.277955 -1.949397    0.0    3.8067    3.9562
# 1 1961-06-15  3.978498 -1.257404 -2.247617    0.0    3.8694    4.0183
# 2 1961-06-16  3.984350 -1.429538 -1.885024    0.0    3.8634    4.0242
# 3 1961-06-19  4.004379 -0.723311 -3.310743    0.0    3.9196    4.0447
# 4 1961-06-20  3.985789 -0.900432 -2.844809    0.0    3.8732    4.0257
#
#    SVEN1F09  SVENF01  SVENF02  ...  SVENY23  SVENY24  SVENY25  SVENY26  \
# 0       NaN   3.5492   3.8825  ...      NaN      NaN      NaN      NaN
# 1       NaN   3.5997   3.9460  ...      NaN      NaN      NaN      NaN
# 2       NaN   3.5957   3.9448  ...      NaN      NaN      NaN      NaN
# 3       NaN   3.6447   3.9842  ...      NaN      NaN      NaN      NaN
# 4       NaN   3.5845   3.9552  ...      NaN      NaN      NaN      NaN
#
#    SVENY27  SVENY28  SVENY29  SVENY30      TAU1    TAU2
# 0      NaN      NaN      NaN      NaN  0.339218 -999.99
# 1      NaN      NaN      NaN      NaN  0.325775 -999.99
# 2      NaN      NaN      NaN      NaN  0.348817 -999.99
# 3      NaN      NaN      NaN      NaN  0.282087 -999.99
# 4      NaN      NaN      NaN      NaN  0.310316 -999.99
#
# [5 rows x 100 columns]

# %%
# filterin for required columns
req_cols = ["Date", "BETA0", "BETA1", "BETA2", "BETA3", "TAU1", "TAU2"]

fed_df = fed_df[req_cols]
fed_df.head()
# Out:
#         Date     BETA0     BETA1     BETA2  BETA3      TAU1    TAU2
# 0 1961-06-14  3.917606 -1.277955 -1.949397    0.0  0.339218 -999.99
# 1 1961-06-15  3.978498 -1.257404 -2.247617    0.0  0.325775 -999.99
# 2 1961-06-16  3.984350 -1.429538 -1.885024    0.0  0.348817 -999.99
# 3 1961-06-19  4.004379 -0.723311 -3.310743    0.0  0.282087 -999.99
# 4 1961-06-20  3.985789 -0.900432 -2.844809    0.0  0.310316 -999.99

# %%
# extrapolating 2 year, (1year, 51 week), 10 year, (9year, 51 week), 1 week interest rates using NSS model
fed_df["r2"] = fed_df.apply(lambda x: fi_utils.interest_rate_NSS(*x[1:7], 2), axis=1)
fed_df["r1"] = fed_df.apply(lambda x: fi_utils.interest_rate_NSS(*x[1:7], 2 - 7/365), axis=1)
fed_df["r10"] = fed_df.apply(lambda x: fi_utils.interest_rate_NSS(*x[1:7], 10), axis=1)
fed_df["r9"] = fed_df.apply(lambda x: fi_utils.interest_rate_NSS(*x[1:7], 10 - 7/365), axis=1)
fed_df["r1w"] = fed_df.apply(lambda x: fi_utils.interest_rate_NSS(*x[1:7], 7/365), axis=1)
fed_df.head()
# Out:
#         Date     BETA0     BETA1     BETA2  BETA3      TAU1    TAU2        r2  \
# 0 1961-06-14  3.917606 -1.277955 -1.949397    0.0  0.339218 -999.99  3.377087
# 1 1961-06-15  3.978498 -1.257404 -2.247617    0.0  0.325775 -999.99  3.413652
# 2 1961-06-16  3.984350 -1.429538 -1.885024    0.0  0.348817 -999.99  3.414231
# 3 1961-06-19  4.004379 -0.723311 -3.310743    0.0  0.282087 -999.99  3.438636
# 4 1961-06-20  3.985789 -0.900432 -2.844809    0.0  0.310316 -999.99  3.410126
#
#          r1       r10        r9       r1w
# 0  3.372202  3.808129  3.807918  2.622033
# 1  3.408506  3.864313  3.864094  2.693771
# 2  3.409104  3.868733  3.868511  2.543441
# 3  3.433360  3.890584  3.890365  3.197538
# 4  3.404856  3.869568  3.869345  3.028249

# %%
plt.figure(figsize=(12, 6))

plt.plot(fed_df["Date"], fed_df["r2"], label="2 Yr Rate")
plt.plot(fed_df["Date"], fed_df["r10"], label="10 Yr Rate")

plt.legend(loc="best")
plt.title("Historical Interest Rates using NSS Model")
plt.xlabel("Year")
plt.ylabel("Interest Rate (%)")

plt.show()

# %%
# filtering for interest rate columns
ir_df = fed_df[["Date", "r1w", "r2", "r1", "r10", "r9"]]
ir_df = ir_df.set_index("Date")
ir_df.tail(20)
# Out:
#                  r1w        r2        r1       r10        r9
# Date
# 2023-12-18  5.671892  4.384592  4.391307  3.977723  3.977136
# 2023-12-19  5.670850  4.368394  4.375056  3.969415  3.968854
# 2023-12-20  5.726222  4.287514  4.294365  3.899536  3.898991
# 2023-12-21  5.697957  4.278413  4.285049  3.929003  3.928429
# 2023-12-22  5.787510  4.249519  4.256128  3.940213  3.939631
# 2023-12-25       NaN       NaN       NaN       NaN       NaN
# 2023-12-26  5.682289  4.271676  4.278153  3.929878  3.929326
# 2023-12-27  5.762079  4.209302  4.216033  3.804430  3.803926
# 2023-12-28  5.784630  4.243779  4.250410  3.850187  3.849726
# 2023-12-29  5.727905  4.213169  4.219646  3.908442  3.907871
# 2024-01-01       NaN       NaN       NaN       NaN       NaN
# 2024-01-02  5.626994  4.289348  4.295477  3.963704  3.963181
# 2024-01-03  5.660152  4.274281  4.280656  3.931534  3.930999
# 2024-01-04  5.579572  4.330172  4.336203  4.013917  4.013339
# 2024-01-05  5.551536  4.343452  4.349167  4.075242  4.074633
# 2024-01-08  5.613219  4.299900  4.305878  4.034411  4.033782
# 2024-01-09  5.635169  4.305631  4.311614  4.034553  4.033941
# 2024-01-10  5.606653  4.307694  4.313555  4.055371  4.054735
# 2024-01-11  5.748272  4.207673  4.213697  4.005767  4.005083
# 2024-01-12  5.856375  4.081347  4.087028  3.981682  3.980919

# %% [markdown]
# ## Steepening Based Strategy
#     Interest rates on long term rise more than short term. So we long short term bonds and short longterm bonds
#
#     -> For this Strat we will be using weekly rebalancing. Close out positions every week and open new ones

# %%
# inital parameters
START_DATE = "1983-12-30"
END_DATE = "2023-12-31"
INITIAL_CAPITAL = 1000000
MARGIN_REQUIREMENT = 0.1

# weekly rebalancing
t_delta = 7/365

# %%
# preparing dataframe with weekly dates
weekly_dates = pd.date_range(start=START_DATE, end=END_DATE, freq="7D")
strat_df = ir_df[START_DATE:END_DATE]
strat_df = strat_df.resample(rule="7D", label="left").first()
strat_df /= 100
strat_df.head()
# Out:
#                  r1w        r2        r1       r10        r9
# Date
# 1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440
# 1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113
# 1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327
# 1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475
# 1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476

# %%
def cash_position(long_value, short_value, capital):
    total_cash = short_value + capital - long_value
    return total_cash

def get_qty(long_price, short_price, hedge_ratio, capital, margin):
    leverage = 1/margin
    
    position_cost = long_price + hedge_ratio * short_price
    units = capital * leverage / position_cost
    return units

def bond_price(t, ytm, c, fv, n_coupons):
    annuity = fv * ((c/n_coupons)/(ytm/n_coupons)) * (1 - 1/(1 + ytm/n_coupons)**(n_coupons*t))
    
    price = annuity + fv/(1 + ytm/n_coupons)**(n_coupons*t)
    return price

def bond_price_ZCB(t, ytm, fv):
    price = fv/(1 + ytm)**t
    return price

def convexity_ZCB(t, ytm):
    c = t * (t+1)/(1 + ytm)**2
    return c

def duration_ZCB(t, ytm, p):
    return t

# %%
# duration
strat_df["d2"] = 2/(1 + strat_df["r2"])
strat_df["d10"] = 10/(1 + strat_df["r10"])

# convexity
strat_df["c2"] = strat_df.apply(lambda x: convexity_ZCB(2, x["r2"]), axis=1)
strat_df["c10"] = strat_df.apply(lambda x: convexity_ZCB(10, x["r10"]), axis=1)

# price
strat_df["p2"] = strat_df.apply(lambda x: bond_price_ZCB(2, x["r2"], 100), axis=1)
strat_df["p10"] = strat_df.apply(lambda x: bond_price_ZCB(10, x["r10"], 100), axis=1)

# DV01
strat_df["DV01_2"] = strat_df["d2"] * strat_df["p2"] * 0.0001
strat_df["DV01_10"] = strat_df["d10"] * strat_df["p10"] * 0.0001

# Hedge Ration
strat_df["hedge_ratio"] = strat_df["DV01_10"]/ strat_df["DV01_2"]
strat_df
# Out:
#                  r1w        r2        r1       r10        r9        d2  \
# Date
# 1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-01  0.058214  0.045101  0.045165  0.042886  0.042878  1.913691
# 2023-12-08  0.056339  0.046496  0.046554  0.042619  0.042613  1.911140
# 2023-12-15  0.056610  0.043754  0.043823  0.039365  0.039359  1.916160
# 2023-12-22  0.057875  0.042495  0.042561  0.039402  0.039396  1.918474
# 2023-12-29  0.057279  0.042132  0.042196  0.039084  0.039079  1.919143
#
#                  d10        c2         c10         p2        p10    DV01_2  \
# Date
# 1983-12-30  8.957010  4.909444   88.250831  81.824060  33.237672  0.014803
# 1984-01-06  8.959628  4.915506   88.302436  81.925107  33.334965  0.014830
# 1984-01-13  8.973988  4.929571   88.585701  82.159518  33.873081  0.014894
# 1984-01-20  8.972813  4.929337   88.562517  82.155613  33.828780  0.014893
# 1984-01-27  8.972800  4.931586   88.562248  82.193108  33.828265  0.014903
# ...              ...       ...         ...        ...        ...       ...
# 2023-12-01  9.588771  5.493321  101.138990  91.555351  65.709722  0.017521
# 2023-12-08  9.591231  5.478682  101.190888  91.311368  65.878485  0.017451
# 2023-12-15  9.621260  5.507505  101.825502  91.791752  67.970329  0.017589
# 2023-12-22  9.620915  5.520814  101.818215  92.013569  67.946013  0.017653
# 2023-12-29  9.623857  5.524666  101.880488  92.077771  68.154048  0.017671
#
#              DV01_10  hedge_ratio
# Date
# 1983-12-30  0.029771     2.011139
# 1984-01-06  0.029867     2.013884
# 1984-01-13  0.030398     2.040908
# 1984-01-20  0.030354     2.038117
# 1984-01-27  0.030353     2.036688
# ...              ...          ...
# 2023-12-01  0.063008     3.596143
# 2023-12-08  0.063186     3.620768
# 2023-12-15  0.065396     3.718055
# 2023-12-22  0.065370     3.703161
# 2023-12-29  0.065590     3.711749
#
# [2088 rows x 14 columns]

# %%
# every week close the position and calculate pnl
# i. pnl from the spread (due to change in yield over the week)
# ii. pnl from the interest accruced on cash
t2_end = 2 - t_delta
t10_end = 10 - t_delta

# price of 2 and 10 year bonds at the end of the week
strat_df["p2_end"] = (strat_df.shift(-1)).apply(lambda x: bond_price_ZCB(t2_end, x["r1"], 100), axis=1)
strat_df["p10_end"] = (strat_df.shift(-1)).apply(lambda x: bond_price_ZCB(t10_end , x["r9"], 100), axis=1)

strat_df = strat_df.reset_index()
strat_df.head()
# Out:
#         Date       r1w        r2        r1       r10        r9        d2  \
# 0 1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1 1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 2 1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 3 1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 4 1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
#
#         d10        c2        c10         p2        p10    DV01_2   DV01_10  \
# 0  8.957010  4.909444  88.250831  81.824060  33.237672  0.014803  0.029771
# 1  8.959628  4.915506  88.302436  81.925107  33.334965  0.014830  0.029867
# 2  8.973988  4.929571  88.585701  82.159518  33.873081  0.014894  0.030398
# 3  8.972813  4.929337  88.562517  82.155613  33.828780  0.014893  0.030354
# 4  8.972800  4.931586  88.562248  82.193108  33.828265  0.014903  0.030353
#
#    hedge_ratio     p2_end    p10_end
# 0     2.011139  82.095579  33.406773
# 1     2.013884  82.327728  33.945025
# 2     2.040908  82.324444  33.900115
# 3     2.038117  82.361442  33.899780
# 4     2.036688  82.426828  33.960753

# %% [markdown]
# ## Initiate Strategy

# %%
# starting with 1M capital, 10% Margin requirement
df = strat_df.copy()
df["cash"] = INITIAL_CAPITAL

# filling in values for first row
p2 = df.loc[0, "p2"]
p10 = df.loc[0, "p10"]
hedge_ratio =  df.loc[0, "hedge_ratio"]
initial_cash = df.loc[0, "cash"]

# quantity 
qty = get_qty(long_price=p10, short_price=p2, hedge_ratio=hedge_ratio, capital=initial_cash, margin=MARGIN_REQUIREMENT)
df.loc[0, "qty"] = qty

# net cash
net_cash_position = qty * (-hedge_ratio * p2 + p10) + initial_cash
df.loc[0, "net_cash_position"] = net_cash_position

# pnl from spread
position_profit = - (df.loc[0, "p10_end"] - df.loc[0, "p10"]) * qty + (df.loc[0, "p2_end"] - df.loc[0, "p2"]) * qty * hedge_ratio
df.loc[0, "position_profit"] = position_profit

# pnl from interest accrued
interest = (7/365) * net_cash_position * df.loc[0, "r1w"]
df.loc[0, "interest_accrued"] = interest

# total pnl
net_profit = interest + position_profit
df.loc[0, "net_profit"] = net_profit

# final cash that will be used next week
final_cash = initial_cash + position_profit + interest
df.loc[1, "cash"] = final_cash
df.head()
# Out:
#         Date       r1w        r2        r1       r10        r9        d2  \
# 0 1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1 1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 2 1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 3 1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 4 1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
#
#         d10        c2        c10  ...   DV01_10  hedge_ratio     p2_end  \
# 0  8.957010  4.909444  88.250831  ...  0.029771     2.011139  82.095579
# 1  8.959628  4.915506  88.302436  ...  0.029867     2.013884  82.327728
# 2  8.973988  4.929571  88.585701  ...  0.030398     2.040908  82.324444
# 3  8.972813  4.929337  88.562517  ...  0.030354     2.038117  82.361442
# 4  8.972800  4.931586  88.562248  ...  0.030353     2.036688  82.426828
#
#      p10_end          cash           qty  net_cash_position  position_profit  \
# 0  33.406773  1.000000e+06  50556.822365      -5.639218e+06     19057.966746
# 1  33.945025  1.009265e+06           NaN                NaN              NaN
# 2  33.900115  1.000000e+06           NaN                NaN              NaN
# 3  33.899780  1.000000e+06           NaN                NaN              NaN
# 4  33.960753  1.000000e+06           NaN                NaN              NaN
#
#    interest_accrued   net_profit
# 0       -9792.48667  9265.480076
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
#
# [5 rows x 23 columns]

# %%
# iteratively repeating the above process to calculate pnl every week and update cash next week
for i, row in df[1:-1].iterrows():
    p2 = df.loc[i, "p2"]
    p10 = df.loc[i, "p10"]
    hedge_ratio =  df.loc[i, "hedge_ratio"]
    initial_cash = df.loc[i, "cash"]
    
    # quantity
    qty = get_qty(long_price=p10, short_price=p2, hedge_ratio=hedge_ratio, capital=initial_cash, margin=MARGIN_REQUIREMENT)
    df.loc[i, "qty"] = qty
    
    # net cash
    net_cash_position = qty * (-hedge_ratio * p2 + p10) + initial_cash
    df.loc[i, "net_cash_position"] = net_cash_position

    # pnl from spread
    position_profit = - (df.loc[i, "p10_end"] - df.loc[i, "p10"]) * qty + (df.loc[i, "p2_end"] - df.loc[i, "p2"]) * qty * hedge_ratio
    df.loc[i, "position_profit"] = position_profit

    # pnl from interest
    interest = (7/365) * net_cash_position * df.loc[i, "r1w"]
    df.loc[i, "interest_accrued"] = interest
    
    # net pnl
    net_profit = interest + position_profit
    df.loc[i, "net_profit"] = net_profit

    # cash available for next week
    final_cash = initial_cash + position_profit + interest
    df.loc[i+1, "cash"] = final_cash

# %%
# calculating weekly and cumulative returns
df["weekly_return"] = (df["net_profit"]/df["cash"])
df["cum_return"] = (df["weekly_return"] + 1).cumprod() - 1
df
# Out:
#            Date       r1w        r2        r1       r10        r9        d2  \
# 0    1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1    1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 2    1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 3    1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 4    1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
# ...         ...       ...       ...       ...       ...       ...       ...
# 2083 2023-12-01  0.058214  0.045101  0.045165  0.042886  0.042878  1.913691
# 2084 2023-12-08  0.056339  0.046496  0.046554  0.042619  0.042613  1.911140
# 2085 2023-12-15  0.056610  0.043754  0.043823  0.039365  0.039359  1.916160
# 2086 2023-12-22  0.057875  0.042495  0.042561  0.039402  0.039396  1.918474
# 2087 2023-12-29  0.057279  0.042132  0.042196  0.039084  0.039079  1.919143
#
#            d10        c2         c10  ...     p2_end    p10_end          cash  \
# 0     8.957010  4.909444   88.250831  ...  82.095579  33.406773  1.000000e+06
# 1     8.959628  4.915506   88.302436  ...  82.327728  33.945025  1.009265e+06
# 2     8.973988  4.929571   88.585701  ...  82.324444  33.900115  1.009700e+06
# 3     8.972813  4.929337   88.562517  ...  82.361442  33.899780  1.015521e+06
# 4     8.972800  4.931586   88.562248  ...  82.426828  33.960753  1.023254e+06
# ...        ...       ...         ...  ...        ...        ...           ...
# 2083  9.588771  5.493321  101.138990  ...  91.380980  65.935210  6.809594e+06
# 2084  9.591231  5.478682  101.190888  ...  91.855189  68.024482  6.619477e+06
# 2085  9.621260  5.507505  101.825502  ...  92.075476  68.000190  6.549333e+06
# 2086  9.620915  5.520814  101.818215  ...  92.139330  68.207923  6.672994e+06
# 2087  9.623857  5.524666  101.880488  ...        NaN        NaN  6.664239e+06
#
#                 qty  net_cash_position  position_profit  interest_accrued  \
# 0      50556.822365      -5.639218e+06     19057.966746      -9792.486670
# 1      50890.079034      -5.690551e+06     10217.360286      -9782.445512
# 2      50096.007532      -5.693491e+06     15507.929228      -9687.259110
# 3      50455.276047      -5.726009e+06     17583.762413      -9850.937879
# 4      50849.962525      -5.768953e+06     17468.337322      -9987.460375
# ...             ...                ...              ...               ...
# 2083  172414.043890      -3.862779e+07   -146991.468966     -43125.391333
# 2084  166949.511037      -3.757853e+07    -29541.510762     -40602.848560
# 2085  160029.785153      -3.718944e+07    164036.989606     -40375.858303
# 2086  163278.825816      -3.786866e+07     33276.463278     -42031.686692
# 2087            NaN                NaN              NaN               NaN
#
#          net_profit  weekly_return  cum_return
# 0       9265.480076       0.009265    0.009265
# 1        434.914774       0.000431    0.009700
# 2       5820.670118       0.005765    0.015521
# 3       7732.824534       0.007615    0.023254
# 4       7480.876947       0.007311    0.030735
# ...             ...            ...         ...
# 2083 -190116.860298      -0.027919    5.619477
# 2084  -70144.359323      -0.010597    5.549333
# 2085  123661.131302       0.018881    5.672994
# 2086   -8755.223414      -0.001312    5.664239
# 2087            NaN            NaN         NaN
#
# [2088 rows x 25 columns]

# %% [markdown]
# ## (i) Cumulative Returns of Steepening Strategy

# %%
plt.figure(figsize=(12, 6))

plt.plot(df["Date"], df["cum_return"], label="Cumulative Return")

plt.legend(loc="best")
plt.title("Cumulative Performance of Steepening Strategy with 10% Margin Requirement")
plt.xlabel("Year")
plt.ylabel("Cumulative Return")

plt.show()

# %% [markdown]
# ## (ii) Convexity Risk of the Spread - (1M USD position in 10 yr bond, 2yr bond is size according to hedge ratio)

# %%
cdf = df[["Date", "c2", "c10", "p2", "p10", "hedge_ratio"]]
cdf["qty"] = 1e6/cdf["p10"]
cdf
# Out:
#            Date        c2         c10         p2        p10  hedge_ratio  \
# 0    1983-12-30  4.909444   88.250831  81.824060  33.237672     2.011139
# 1    1984-01-06  4.915506   88.302436  81.925107  33.334965     2.013884
# 2    1984-01-13  4.929571   88.585701  82.159518  33.873081     2.040908
# 3    1984-01-20  4.929337   88.562517  82.155613  33.828780     2.038117
# 4    1984-01-27  4.931586   88.562248  82.193108  33.828265     2.036688
# ...         ...       ...         ...        ...        ...          ...
# 2083 2023-12-01  5.493321  101.138990  91.555351  65.709722     3.596143
# 2084 2023-12-08  5.478682  101.190888  91.311368  65.878485     3.620768
# 2085 2023-12-15  5.507505  101.825502  91.791752  67.970329     3.718055
# 2086 2023-12-22  5.520814  101.818215  92.013569  67.946013     3.703161
# 2087 2023-12-29  5.524666  101.880488  92.077771  68.154048     3.711749
#
#                qty
# 0     30086.343371
# 1     29998.531502
# 2     29521.967942
# 3     29560.628649
# 4     29561.078391
# ...            ...
# 2083  15218.448247
# 2084  15179.462562
# 2085  14712.301803
# 2086  14717.567101
# 2087  14672.642764
#
# [2088 rows x 7 columns]

# %%
cdf["convexity_risk"] = 0.5 * (0.001)**2 * (hedge_ratio * cdf["qty"] * cdf["p2"] * cdf["c2"] - cdf["c10"] * 1e6)

# %%
plt.figure(figsize=(12, 6))

plt.plot(cdf["Date"], cdf["convexity_risk"], label="Convexity Risk")

plt.legend(loc="best")
plt.title("Convexity Risk of Steepening Strategy for 1M position in Back Leg")
plt.xlabel("Year")
plt.ylabel("Risk")

plt.show()

# %% [markdown]
# ## (iii) Return Decomposition

# %%
# getting delta in yield over the week
df["dr2"] = df["r2"] - df["r1"]
df["dr10"] = df["r10"] - df["r9"]
df
# Out:
#            Date       r1w        r2        r1       r10        r9        d2  \
# 0    1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1    1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 2    1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 3    1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 4    1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
# ...         ...       ...       ...       ...       ...       ...       ...
# 2083 2023-12-01  0.058214  0.045101  0.045165  0.042886  0.042878  1.913691
# 2084 2023-12-08  0.056339  0.046496  0.046554  0.042619  0.042613  1.911140
# 2085 2023-12-15  0.056610  0.043754  0.043823  0.039365  0.039359  1.916160
# 2086 2023-12-22  0.057875  0.042495  0.042561  0.039402  0.039396  1.918474
# 2087 2023-12-29  0.057279  0.042132  0.042196  0.039084  0.039079  1.919143
#
#            d10        c2         c10  ...          cash            qty  \
# 0     8.957010  4.909444   88.250831  ...  1.000000e+06   50556.822365
# 1     8.959628  4.915506   88.302436  ...  1.009265e+06   50890.079034
# 2     8.973988  4.929571   88.585701  ...  1.009700e+06   50096.007532
# 3     8.972813  4.929337   88.562517  ...  1.015521e+06   50455.276047
# 4     8.972800  4.931586   88.562248  ...  1.023254e+06   50849.962525
# ...        ...       ...         ...  ...           ...            ...
# 2083  9.588771  5.493321  101.138990  ...  6.809594e+06  172414.043890
# 2084  9.591231  5.478682  101.190888  ...  6.619477e+06  166949.511037
# 2085  9.621260  5.507505  101.825502  ...  6.549333e+06  160029.785153
# 2086  9.620915  5.520814  101.818215  ...  6.672994e+06  163278.825816
# 2087  9.623857  5.524666  101.880488  ...  6.664239e+06            NaN
#
#       net_cash_position  position_profit  interest_accrued     net_profit  \
# 0         -5.639218e+06     19057.966746      -9792.486670    9265.480076
# 1         -5.690551e+06     10217.360286      -9782.445512     434.914774
# 2         -5.693491e+06     15507.929228      -9687.259110    5820.670118
# 3         -5.726009e+06     17583.762413      -9850.937879    7732.824534
# 4         -5.768953e+06     17468.337322      -9987.460375    7480.876947
# ...                 ...              ...               ...            ...
# 2083      -3.862779e+07   -146991.468966     -43125.391333 -190116.860298
# 2084      -3.757853e+07    -29541.510762     -40602.848560  -70144.359323
# 2085      -3.718944e+07    164036.989606     -40375.858303  123661.131302
# 2086      -3.786866e+07     33276.463278     -42031.686692   -8755.223414
# 2087                NaN              NaN               NaN            NaN
#
#       weekly_return  cum_return       dr2      dr10
# 0          0.009265    0.009265  0.000092  0.000004
# 1          0.000431    0.009700  0.000093  0.000005
# 2          0.005765    0.015521  0.000090  0.000005
# 3          0.007615    0.023254  0.000094  0.000003
# 4          0.007311    0.030735  0.000092  0.000004
# ...             ...         ...       ...       ...
# 2083      -0.027919    5.619477 -0.000064  0.000009
# 2084      -0.010597    5.549333 -0.000058  0.000006
# 2085       0.018881    5.672994 -0.000069  0.000006
# 2086      -0.001312    5.664239 -0.000066  0.000006
# 2087            NaN         NaN -0.000065  0.000006
#
# [2088 rows x 27 columns]

# %%
df["spread_return"] = (- (df["DV01_2"] * df["hedge_ratio"] * df["dr2"] * 100 - df["DV01_10"] * df["dr10"] * 100) * df["qty"])

# %%
df["convexity_return"] = (0.5 * df["qty"] * (df["c2"] * df["hedge_ratio"] * df["p2"] * df["dr2"]**2 - df["c10"] * df["dr10"]**2 * df["p10"]))

# %%
df["time_return"] = df["interest_accrued"]

# %%
df["residual_return"] = (df["net_profit"] - (df["spread_return"] + df["convexity_return"] + df["time_return"]))

# %%
ret_df = df[["Date", "net_profit", "spread_return", "convexity_return", "time_return", "residual_return"]].set_index("Date").iloc[:-1]
ret_df
# Out:
#                net_profit  spread_return  convexity_return   time_return  \
# Date
# 1983-12-30    9265.480076     -13.163689          0.171077  -9792.486670
# 1984-01-06     434.914774     -13.388313          0.177030  -9782.445512
# 1984-01-13    5820.670118     -12.876135          0.164433  -9687.259110
# 1984-01-20    7732.824534     -13.863916          0.181833  -9850.937879
# 1984-01-27    7480.876947     -13.655036          0.177277  -9987.460375
# ...                   ...            ...               ...           ...
# 2023-11-24   97304.044183      71.082092          0.521256 -39007.518088
# 2023-12-01 -190116.860298      78.927066          0.594571 -43125.391333
# 2023-12-08  -70144.359323      67.681153          0.484217 -40602.848560
# 2023-12-15  123661.131302      78.018744          0.691600 -40375.858303
# 2023-12-22   -8755.223414      76.750322          0.651579 -42031.686692
#
#             residual_return
# Date
# 1983-12-30     19070.959359
# 1984-01-06     10230.571569
# 1984-01-13     15520.640929
# 1984-01-20     17597.444496
# 1984-01-27     17481.815082
# ...                     ...
# 2023-11-24    136239.958923
# 2023-12-01   -147070.990602
# 2023-12-08    -29609.676132
# 2023-12-15    163958.279262
# 2023-12-22     33199.061377
#
# [2087 rows x 5 columns]

# %%
cum_ret = (ret_df.cumsum()/1e6)
plt.figure(figsize=(12, 6))

plt.plot(cum_ret.index, cum_ret["spread_return"], label="Spread Return")
plt.plot(cum_ret.index, cum_ret["convexity_return"], label="Convexity Return")
plt.plot(cum_ret.index, cum_ret["time_return"], label="Time Return")
plt.plot(cum_ret.index, cum_ret["residual_return"], label="Residual Return")
plt.plot(cum_ret.index, cum_ret["net_profit"], label="Cumulative Return")
plt.title("Return Decomposition for Steepening Strategy")
plt.ylabel("Return")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Return Contribution

# %%
return_contribution = dict()
total = cum_ret.iloc[-1, 0]
spread = cum_ret.iloc[-1, 1]
convexity = cum_ret.iloc[-1, 2]
time = cum_ret.iloc[-1, 3]
residual = cum_ret.iloc[-1, 4]

return_contribution["Spread"] = spread/total * 100
return_contribution["Convexity"] = convexity/total * 100
return_contribution["Time"] = time/total * 100
return_contribution["Residual"] = residual/total * 100

# %%
return_contribution
# Out:
# {'Spread': -0.8816718230406704,
#  'Convexity': 0.010555428738381709,
#  'Time': -597.5677189481765,
#  'Residual': 698.4388353424803}

# %%
plt.figure(figsize=(12, 6))
plt.bar(*zip(*return_contribution.items()), width=0.1)
plt.axhline(color="black")
plt.title("Return Contribution for Steepening Strategy")
plt.ylabel("% Contribution")
plt.show()

# %% [markdown]
# ## Changing Margin Requirement to 2%

# %%
MARGIN_REQUIREMENT = 0.02

df = strat_df.copy()
df["cash"] = INITIAL_CAPITAL

p2 = df.loc[0, "p2"]
p10 = df.loc[0, "p10"]
hedge_ratio =  df.loc[0, "hedge_ratio"]

initial_cash = df.loc[0, "cash"]

qty = get_qty(long_price=p10, short_price=p2, hedge_ratio=hedge_ratio, capital=initial_cash, margin=MARGIN_REQUIREMENT)
net_cash_position = qty * (-hedge_ratio * p2 + p10) + initial_cash

df.loc[0, "qty"] = qty
df.loc[0, "net_cash_position"] = net_cash_position

position_profit = - (df.loc[0, "p10_end"] - df.loc[0, "p10"]) * qty + (df.loc[0, "p2_end"] - df.loc[0, "p2"]) * qty * hedge_ratio
df.loc[0, "position_profit"] = position_profit

interest = (7/365) * net_cash_position * df.loc[0, "r1w"]
df.loc[0, "interest_accrued"] = interest

net_profit = interest + position_profit
df.loc[0, "net_profit"] = net_profit

final_cash = initial_cash + position_profit + interest
df.loc[1, "cash"] = final_cash


for i, row in df[1:-1].iterrows():
    p2 = df.loc[i, "p2"]
    p10 = df.loc[i, "p10"]
    hedge_ratio =  df.loc[i, "hedge_ratio"]

    initial_cash = df.loc[i, "cash"]
    
    qty = get_qty(long_price=p10, short_price=p2, hedge_ratio=hedge_ratio, capital=initial_cash, margin=MARGIN_REQUIREMENT)
    net_cash_position = qty * (-hedge_ratio * p2 + p10) + initial_cash

    df.loc[i, "qty"] = qty
    df.loc[i, "net_cash_position"] = net_cash_position

    position_profit = - (df.loc[i, "p10_end"] - df.loc[i, "p10"]) * qty + (df.loc[i, "p2_end"] - df.loc[i, "p2"]) * qty * hedge_ratio
    df.loc[i, "position_profit"] = position_profit

    interest = (7/365) * net_cash_position * df.loc[i, "r1w"]
    df.loc[i, "interest_accrued"] = interest
    
    net_profit = interest + position_profit
    df.loc[i, "net_profit"] = net_profit

    final_cash = initial_cash + position_profit + interest
    df.loc[i+1, "cash"] = final_cash
    
df["weekly_return"] = (df["net_profit"]/df["cash"])
df["cum_return"] = (df["weekly_return"] + 1).cumprod() - 1
df
# Out:
#            Date       r1w        r2        r1       r10        r9        d2  \
# 0    1983-12-30  0.090546  0.105502  0.105410  0.116444  0.116440  1.809133
# 1    1984-01-06  0.089637  0.104820  0.104727  0.116118  0.116113  1.810250
# 2    1984-01-13  0.088719  0.103243  0.103153  0.114332  0.114327  1.812838
# 3    1984-01-20  0.089706  0.103269  0.103175  0.114478  0.114475  1.812795
# 4    1984-01-27  0.090272  0.103017  0.102925  0.114479  0.114476  1.813208
# ...         ...       ...       ...       ...       ...       ...       ...
# 2083 2023-12-01  0.058214  0.045101  0.045165  0.042886  0.042878  1.913691
# 2084 2023-12-08  0.056339  0.046496  0.046554  0.042619  0.042613  1.911140
# 2085 2023-12-15  0.056610  0.043754  0.043823  0.039365  0.039359  1.916160
# 2086 2023-12-22  0.057875  0.042495  0.042561  0.039402  0.039396  1.918474
# 2087 2023-12-29  0.057279  0.042132  0.042196  0.039084  0.039079  1.919143
#
#            d10        c2         c10  ...     p2_end    p10_end          cash  \
# 0     8.957010  4.909444   88.250831  ...  82.095579  33.406773  1.000000e+06
# 1     8.959628  4.915506   88.302436  ...  82.327728  33.945025  1.039381e+06
# 2     8.973988  4.929571   88.585701  ...  82.324444  33.900115  1.034474e+06
# 3     8.972813  4.929337   88.562517  ...  82.361442  33.899780  1.057251e+06
# 4     8.972800  4.931586   88.562248  ...  82.426828  33.960753  1.090228e+06
# ...        ...       ...         ...  ...        ...        ...           ...
# 2083  9.588771  5.493321  101.138990  ...  91.380980  65.935210  8.446547e+05
# 2084  9.591231  5.478682  101.190888  ...  91.855189  68.024482  7.229733e+05
# 2085  9.621260  5.507505  101.825502  ...  92.075476  68.000190  6.815431e+05
# 2086  9.620915  5.520814  101.818215  ...  92.139330  68.207923  7.429261e+05
# 2087  9.623857  5.524666  101.880488  ...        NaN        NaN  7.347540e+05
#
#                 qty  net_cash_position  position_profit  interest_accrued  \
# 0     252784.111824      -3.219609e+07     95289.833731     -55908.422580
# 1     262043.056085      -3.345930e+07     52611.203704     -57518.811660
# 2     256625.666886      -3.330381e+07     79442.112779     -56665.171101
# 3     262642.893504      -3.403551e+07     91531.562222     -58554.169750
# 4     270891.029569      -3.509363e+07     93058.394681     -60755.609622
# ...             ...                ...              ...               ...
# 2083  106930.262596      -2.733537e+07    -91163.318378     -30518.141946
# 2084   91170.366769      -2.341336e+07    -16132.484332     -25297.662664
# 2085   83265.884700      -2.207639e+07     85350.892960     -23967.914221
# 2086   90891.810293      -2.405191e+07     18523.883745     -26696.015052
# 2087            NaN                NaN              NaN               NaN
#
#          net_profit  weekly_return  cum_return
# 0      39381.411151       0.039381    0.039381
# 1      -4907.607956      -0.004722    0.034474
# 2      22776.941678       0.022018    0.057251
# 3      32977.392473       0.031192    0.090228
# 4      32302.785059       0.029629    0.122531
# ...             ...            ...         ...
# 2083 -121681.460324      -0.144061   -0.277027
# 2084  -41430.146996      -0.057305   -0.318457
# 2085   61382.978739       0.090065   -0.257074
# 2086   -8172.131307      -0.011000   -0.265246
# 2087            NaN            NaN         NaN
#
# [2088 rows x 25 columns]

# %%
plt.figure(figsize=(12, 6))

plt.plot(df["Date"], df["cum_return"], label="Cumulative Return")

plt.legend(loc="best")
plt.title("Cumulative Performance of Steepening Strategy with 2% Margin Requirement")
plt.xlabel("Year")
plt.ylabel("Cumulative Return")

plt.show()
